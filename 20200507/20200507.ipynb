# %%
import pandas as pd

# %%
data = pd.read_csv('ich.csv', encoding='cp949') #loadtxt, genfromtxt

# %%
data ## 전체를 데이터프레임 ## 한줄은 series
# Out:
#           순번         분전함    등주         위도          경도     데이터기준일자
# 0          1  월미로21(YB1)  좌103  37.472676  126.606904  2020-04-27
# 1          2  월미로21(YB1)  좌104  37.473054  126.606874  2020-04-27
# 2          3  월미로21(YB1)  좌105  37.473430  126.606698  2020-04-27
# 3          4  월미로21(YB1)  좌106  37.473816  126.606510  2020-04-27
# 4          5  월미로21(YB1)  좌107  37.474174  126.606356  2020-04-27
# ...      ...         ...   ...        ...         ...         ...
# 15725  15726   흰바위로LP_14    26  37.478098  126.502607  2020-04-27
# 15726  15727   흰바위로LP_14    27  37.477987  126.502791  2020-04-27
# 15727  15728   흰바위로LP_14    28  37.477861  126.503011  2020-04-27
# 15728  15729   흰바위로LP_14    29  37.477743  126.503217  2020-04-27
# 15729  15730   흰바위로LP_14    30  37.477630  126.503417  2020-04-27
#
# [15730 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15730 entries, 0 to 15729
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   순번       15730 non-null  int64
#  1   분전함      15730 non-null  object
#  2   등주       13244 non-null  object
#  3   위도       15730 non-null  float64
#  4   경도       15730 non-null  float64
#  5   데이터기준일자  15730 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 737.5+ KB

# %%
data.dtypes
# Out:
# 순번           int64
# 분전함         object
# 등주          object
# 위도         float64
# 경도         float64
# 데이터기준일자     object
# dtype: object

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")    # 붓꽃 데이터

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
type(iris['sepal_length'])
# Out:
# pandas.core.series.Series

# %%
iris[['sepal_length']]
# Out:
#      sepal_length
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# ..            ...
# 145           6.7
# 146           6.3
# 147           6.5
# 148           6.2
# 149           5.9
#
# [150 rows x 1 columns]

# %%
iris.sepal_length # 공백.특수문자, numpy 지원하는 property 명하고 같으면 안됨
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
iris.iloc[0,0]
# Out:
# 5.1

# %%
tips = sns.load_dataset("tips")    # 붓꽃 데이터

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.rename({'size':'size_'}, axis = 1)
# Out:
#      total_bill   tip     sex smoker   day    time  size_
# 0         16.99  1.01  Female     No   Sun  Dinner      2
# 1         10.34  1.66    Male     No   Sun  Dinner      3
# 2         21.01  3.50    Male     No   Sun  Dinner      3
# 3         23.68  3.31    Male     No   Sun  Dinner      2
# 4         24.59  3.61  Female     No   Sun  Dinner      4
# ..          ...   ...     ...    ...   ...     ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner      3
# 240       27.18  2.00  Female    Yes   Sat  Dinner      2
# 241       22.67  2.00    Male    Yes   Sat  Dinner      2
# 242       17.82  1.75    Male     No   Sat  Dinner      2
# 243       18.78  3.00  Female     No  Thur  Dinner      2
#
# [244 rows x 7 columns]

# %%
tips.rename(columns={'size':'size_'})
# Out:
#      total_bill   tip     sex smoker   day    time  size_
# 0         16.99  1.01  Female     No   Sun  Dinner      2
# 1         10.34  1.66    Male     No   Sun  Dinner      3
# 2         21.01  3.50    Male     No   Sun  Dinner      3
# 3         23.68  3.31    Male     No   Sun  Dinner      2
# 4         24.59  3.61  Female     No   Sun  Dinner      4
# ..          ...   ...     ...    ...   ...     ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner      3
# 240       27.18  2.00  Female    Yes   Sat  Dinner      2
# 241       22.67  2.00    Male    Yes   Sat  Dinner      2
# 242       17.82  1.75    Male     No   Sat  Dinner      2
# 243       18.78  3.00  Female     No  Thur  Dinner      2
#
# [244 rows x 7 columns]

# %%
tips[tips.sex == 'Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
iris.describe(include=['float64','object']).T
# Out:
#              count unique     top freq     mean       std  min  25%   50%  \
# sepal_length   150    NaN     NaN  NaN  5.84333  0.828066  4.3  5.1   5.8
# sepal_width    150    NaN     NaN  NaN  3.05733  0.435866    2  2.8     3
# petal_length   150    NaN     NaN  NaN    3.758    1.7653    1  1.6  4.35
# petal_width    150    NaN     NaN  NaN  1.19933  0.762238  0.1  0.3   1.3
# species        150      3  setosa   50      NaN       NaN  NaN  NaN   NaN
#
#               75%  max
# sepal_length  6.4  7.9
# sepal_width   3.3  4.4
# petal_length  5.1  6.9
# petal_width   1.8  2.5
# species       NaN  NaN

# %%
iris.describe(include=['O']).T
# Out:
#         count unique     top freq
# species   150      3  setosa   50

# %%
iris.describe(include='all').T
# Out:
#              count unique     top freq     mean       std  min  25%   50%  \
# sepal_length   150    NaN     NaN  NaN  5.84333  0.828066  4.3  5.1   5.8
# sepal_width    150    NaN     NaN  NaN  3.05733  0.435866    2  2.8     3
# petal_length   150    NaN     NaN  NaN    3.758    1.7653    1  1.6  4.35
# petal_width    150    NaN     NaN  NaN  1.19933  0.762238  0.1  0.3   1.3
# species        150      3  setosa   50      NaN       NaN  NaN  NaN   NaN
#
#               75%  max
# sepal_length  6.4  7.9
# sepal_width   3.3  4.4
# petal_length  5.1  6.9
# petal_width   1.8  2.5
# species       NaN  NaN

# %%
import matplotlib.pyplot as plt

# %%
t = iris.sepal_length.plot

# %%
t.area()

# %%
data = pd.read_csv('yanolja.csv', encoding = 'cp949')

# %%
data
# Out:
#                 업소명 업종명  서비스대상구분 외국어안내서비스  \
# 0          로또게스트하우스  민박      외국인       영어
# 1          방방게스트하우스  민박      외국인       영어
# 2         행궁채게스트하우스  민박      외국인       영어
# 3       JUNHO HOUSE  민박      외국인       영어
# 4            웰컴 하우스  민박      외국인       영어
# 5               송아당  민박      외국인       영어
# 6            더펜트하우스  민박      외국인      일본어
# 7   J&K, SWEET HOME  민박      외국인       영어
# 8         로또Ⅱ게스트하우스  민박      외국인       영어
# 9          선미의 홈스테이  민박      외국인       영어
# 10        수원역게스트하우스  민박      외국인      중국어
# 11              유어턴  민박      외국인       영어
# 12            까사브랑카  민박      외국인       영어
# 13         수원 한옥 미가  펜션  내국인+외국인      NaN
# 14            한옥노아재  펜션  내국인+외국인      NaN
# 15              수원사  펜션  내국인+외국인      NaN
# 16              매홀재  펜션  내국인+외국인      NaN
# 17              여여제  펜션  내국인+외국인      NaN
#
#                                              소재지도로명주소  \
# 0   경기도 수원시 영통구 센트럴파크로127번길 103, 4층 401호 (이의동, 수정하우스)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   업소명       18 non-null     object
#  1   업종명       18 non-null     object
#  2   서비스대상구분   18 non-null     object
#  3   외국어안내서비스  13 non-null     object
#  4   소재지도로명주소  18 non-null     object
#  5   소재지지번주소   18 non-null     object
#  6   전화번호      11 non-null     object
#  7   객실수       18 non-null     int64
#  8   부대시설      0 non-null      float64
#  9   주차장보유여부   0 non-null      float64
#  10  결제방법      0 non-null      float64
#  11  홈페이지주소    0 non-null      float64
#  12  주변관광정보    0 non-null      float64
#  13  위도        18 non-null     float64
#  14  경도        18 non-null     float64
#  15  데이터기준일자   18 non-null     object
# dtypes: float64(7), int64(1), object(8)
# memory usage: 2.4+ KB

# %%
t = data['업종명'].value_counts()

# %%
t.plot.hist()

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x = tips.groupby('sex').mean()

# %%
x
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
x['ratio'] = x.tip /x.total_bill

# %%
x['ratio_s'] = x.tip /x['size']

# %%
x.tip.plot.pie()

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.groupby('smoker').median()
# Out:
#         total_bill   tip  size
# smoker
# Yes          17.92  3.00     2
# No           17.59  2.74     2

# %%
tips.groupby(['smoker','sex']).median()
# Out:
#                total_bill   tip  size
# smoker sex
# Yes    Male         20.39  3.00     2
#        Female       16.27  2.88     2
# No     Male         18.24  2.74     2
#        Female       16.69  2.68     2

# %%
tips.sex = tips.sex.map({'Female':0,'Male':1})

# %%
tips
# Out:
#      total_bill   tip sex smoker   day    time  size
# 0         16.99  1.01   0     No   Sun  Dinner     2
# 1         10.34  1.66   1     No   Sun  Dinner     3
# 2         21.01  3.50   1     No   Sun  Dinner     3
# 3         23.68  3.31   1     No   Sun  Dinner     2
# 4         24.59  3.61   0     No   Sun  Dinner     4
# ..          ...   ...  ..    ...   ...     ...   ...
# 239       29.03  5.92   1     No   Sat  Dinner     3
# 240       27.18  2.00   0    Yes   Sat  Dinner     2
# 241       22.67  2.00   1    Yes   Sat  Dinner     2
# 242       17.82  1.75   1     No   Sat  Dinner     2
# 243       18.78  3.00   0     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.smoker = tips.smoker.map({'No':0,'Yes':1})

# %%
tips.day = tips.day.map({'Thur':0,'Fri':1, 'Sat':2, 'Sun':3})
